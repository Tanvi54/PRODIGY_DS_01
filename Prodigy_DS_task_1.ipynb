# %% [markdown]
# **DATASET LINK**

# %%
#https://www.kaggle.com/datasets/yaminh/heart-disease-dataset

# %% [markdown]
# **Install & Import Libraries**

# %%
# !pip install pandas seaborn matplotlib

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Load Dataset**

# %%
df = pd.read_csv('heart_data.csv')  # heart disease dataset from Kaggle
print(df.head())
print(df.dtypes)
# Out:
#    rest_bp  chest_pain  thalassemia  age  fasting_bs  max_hr  exercise_angina  \
# 0      106           3            0   67           0     142                0
# 1      120           2            0   50           0     158                0
# 2      126           3            2   35           0     156                1
# 3      150           3            2   63           0     154                0
# 4      140           3            2   46           0     120                1
#
#    gender  st_slope  cholesterol  st_depression  rest_ecg  num_vessels  \
# 0       0         0          223            0.3         0            2
# 1       0         1          219            1.6         0            0
# 2       1         0          282            0.0         2            0
# 3       0         1          407            4.0         2            3
# 4       1         1          311            1.8         0            2
#
#    diagnosis
# 0          0
# 1          0
# 2          1
# ...

# %% [markdown]
# **Histogram — Age Distribution**

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['age'], bins=20, kde=True, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age (years)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Bar Chart — Gender Distribution**

# %%
df['gender_label'] = df['gender'].map({1: 'Male', 0: 'Female'})
plt.figure(figsize=(6, 5))
sns.countplot(data=df, x='gender_label', palette={"Male":'lightblue', "Female":'pink'})
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipython-input-36-1601153608.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='gender_label', palette={"Male":'lightblue', "Female":'pink'})

# %% [markdown]
# **Age Distribution by Diagnosis**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='age', hue='diagnosis', bins=20, kde=False, palette={0: 'tomato', 1: 'dodgerblue'}, multiple='stack')
plt.title('Age Distribution by Heart Disease Diagnosis')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title='Diagnosis', labels=['No Disease', 'Heart Disease'])
plt.grid(True)
plt.show()

# %% [markdown]
# **Bar Chart — Diagnosis Count**

# %%
sns.countplot(x='diagnosis', data=df, palette='coolwarm')
plt.title('Heart Disease Diagnosis Distribution')
plt.xlabel('Diagnosis (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipython-input-26-3987884028.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='diagnosis', data=df, palette='coolwarm')

# %% [markdown]
# **Bar Plot — Cholesterol by Diagnosis**

# %%
sns.barplot(x='diagnosis', y='cholesterol', data=df, palette='Set2')
plt.title('Cholesterol Levels by Diagnosis')
plt.xlabel('Diagnosis (0 = No, 1 = Yes)')
plt.ylabel('Cholesterol')
plt.show()
# Out:
# /tmp/ipython-input-31-2227996449.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='diagnosis', y='cholesterol', data=df, palette='Set2')

# %% [markdown]
# **Histogram — Resting Blood Pressure**

# %%
sns.histplot(df['rest_bp'], bins=25, kde=False, color='teal')
plt.title('Distribution of Resting Blood Pressure')
plt.xlabel('Resting BP')
plt.ylabel('Frequency')
plt.show()
